# %% [markdown]
# # **Intro to Einsum**

# %% [markdown]
# Pros
# - Convenient and compact
# - Stand-in for many tensor ops including matrix mult, element-wise mult, dot product, outer product
# - You can even combine all of the above in a single einsum call.
# - No need to permute outputs for batch matrix mult
#
# Cons:
# - A little confusing
# - Can be a little slower since it's not optimized, but in practice we can overcome this (and make it faster) by combining ops in a single call

# %% [markdown]
# # **Matrix Multiply**

# %% [markdown]
# $$\LARGE{M_{ij} = \Sigma_k \; A_{ik}B_{kj}}$$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

A = np.random.randint(5, size=(3,5))
B = np.random.randint(5, size=(5,2))
M = np.empty((3,2))

for i in range(3):
  for j in range(2):
    total = 0
    for k in range(5):
      total += A[i,k]*B[k,j]

    M[i,j] = total

# %%
print(f"""
A: {A}

B: {B}

M1: {M}
""")
# Out:
# A: [[4 1 2 2 2]
#  [3 2 4 2 2]
#  [4 3 3 0 3]]
#
# B: [[4 3]
#  [0 4]
#  [1 1]
#  [3 3]
#  [2 1]]
#
# M1: [[28. 26.]
#  [26. 29.]
#  [25. 30.]]

# %% [markdown]
# $$\LARGE{M_{ij} = A_{ik}B_{kj}}$$

# %%
M2 = np.einsum('ik, kj -> ij', A, B)

# %%
print(f"M2: {M2}")
# Out:
# M2: [[28 26]
#  [26 29]
#  [25 30]]

# %% [markdown]
# # **Outer Product**

# %% [markdown]
# $$
# {\displaystyle \mathbf {u} ={\begin{bmatrix}u_{1}\\u_{2}\\\vdots \\u_{m}\end{bmatrix}},\quad \mathbf {v} ={\begin{bmatrix}v_{1}\\v_{2}\\\vdots \\v_{n}\end{bmatrix}}}
# $$

# %% [markdown]
# $${\displaystyle \mathbf {u} \otimes \mathbf {v} =\mathbf {A} ={\begin{bmatrix}u_{1}v_{1}&u_{1}v_{2}&\dots &u_{1}v_{n}\\u_{2}v_{1}&u_{2}v_{2}&\dots &u_{2}v_{n}\\\vdots &\vdots &\ddots &\vdots \\u_{m}v_{1}&u_{m}v_{2}&\dots &u_{m}v_{n}\end{bmatrix}}}$$

# %%
import numpy as np

u = np.random.randint(5, size=(5))
v = np.random.randint(5, size=(5))
A = np.empty((5,5))

# %%
for i in range(5):
  for j in range(3):
    total = 0
    total += u[i] * v[j]
    A[i,j] = total

# %%
print(f"""
u: {u}

v: {v}

A: {A}
""")
# Out:
# u: [0 3 2 0 4]
#
# v: [1 0 0 2 4]
#
# A: [[0. 0. 0. 0. 0.]
#  [3. 0. 0. 0. 0.]
#  [2. 0. 0. 0. 0.]
#  [0. 0. 0. 0. 0.]
#  [4. 0. 0. 0. 0.]]

# %%
A = np.einsum('i,j->ij', u, v)

# %%
print(f"A: {A}")
# Out:
# A: [[ 0  0  0  0  0]
#  [ 3  0  0  6 12]
#  [ 2  0  0  4  8]
#  [ 0  0  0  0  0]
#  [ 4  0  0  8 16]]

# %% [markdown]
# # **Einsum Rules**
# 1. Repeating letters, such as k, indicate all of the k values will be multiplied and those products will be the output. It should be equal length for both inputs.
# 2. Omitting a letter means that axis will be summed.
# 3. We can return the unsummed axes in any order.

# %%
np.einsum('ij,jk->ik', A, B)
# Out:
# array([[ 0,  0],
#        [54, 39],
#        [36, 26],
#        [ 0,  0],
#        [72, 52]])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = np.ones(3)
sum_x = np.einsum('i->', x)

print(sum_x)
# Out:
# 3.0

# %%
x = np.ones((1,3))
print(x.shape)

x = np.einsum('ij->ji', x)

print(x.shape)
print(x)
# Out:
# (1, 3)
# (3, 1)
# [[1.]
#  [1.]
#  [1.]]

# %%
x = np.ones((2,3,5))
print(x.shape)

x = np.einsum('ijk->kji', x)

print(x.shape)
# Out:
# (2, 3, 5)
# (5, 3, 2)

# %% [markdown]
# # **Some More Operations**

# %%
import torch

# %%
# Permuting Tensors
x = torch.randint(0, 5, (2,3))
print(x)
# Out:
# tensor([[3, 3, 0],
#         [2, 4, 2]])

# %%
print(torch.einsum('ij->ji', x))
# Out:
# tensor([[3, 2],
#         [3, 4],
#         [0, 2]])

# %%
# Summation
print(torch.einsum('ij->', x))
# Out:
# tensor(14)

# %%
# Column Sum
print(torch.einsum('ij->j', x))
# Out:
# tensor([5, 7, 2])

# %%
# Row Sum
print(torch.einsum('ij->i', x))
# Out:
# tensor([6, 8])

# %%
# Matrix-Vector Multiply
v = torch.randint(0, 5, (1,3))
v
# Out:
# tensor([[0, 3, 2]])

# %%
x
# Out:
# tensor([[3, 3, 0],
#         [2, 4, 2]])

# %%
torch.einsum('ij, kj -> ik', x, v)
# Out:
# tensor([[ 9],
#         [16]])

# %%
# Matrix-Matrix Multiplication
torch.einsum("ij, kj -> ik", x, x) # (2,3) @ (3,2) --> (2,2)
# Out:
# tensor([[18, 18],
#         [18, 24]])

# %%
# Dot product first row with first row of matrix
torch.einsum('i,i->', x[0], x[0])
# Out:
# tensor(18)

# %%
# Dot product with matrix
torch.einsum('ij, ij ->', x, x)
# Out:
# tensor(42)

# %%
# Hadamard Product (element-wise mult)
torch.einsum('ij, ij -> ij', x, x)
# Out:
# tensor([[ 9,  9,  0],
#         [ 4, 16,  4]])

# %% [markdown]
# # **Einops**

# %%
# !pip install einops

# %%
import numpy as np
from utils import display_np_arrays_as_images
display_np_arrays_as_images()

# %%
ims = np.load('resources/test_images.npy', allow_pickle=False)
# There are 6 images of shape 96x96 with 3 color channels packed into tensor
print(ims.shape, ims.dtype)
# Out:
# (6, 96, 96, 3) float64

# %%
# display the first image (whole 4d tensor can't be rendered)
ims[0]

# %%
# second image in a batch
ims[1]

# %%
# we'll use three operations
from einops import rearrange, reduce, repeat

# %%
# rearrange, as its name suggests, rearranges elements
# below we swapped height and width.
# In other words, transposed first two axes (dimensions)
rearrange(ims[0], 'h w c -> w h c')

# %%
# einops allows seamlessly composing batch and height to a new height dimension
# We just rendered all images by collapsing to 3d tensor!
rearrange(ims, 'b h w c -> (b h) w c')

# %%
# or compose a new dimension of batch and width
rearrange(ims, 'b h w c -> h (b w) c')

# %%
# resulting dimensions are computed very simply
# length of newly composed axis is a product of components
# [6, 96, 96, 3] -> [96, (6 * 96), 3]
rearrange(ims, 'b h w c -> h (b w) c').shape
# Out:
# (96, 576, 3)

# %%
# we can compose more than two axes.
# let's flatten 4d array into 1d, resulting array has as many elements as the original
rearrange(ims, 'b h w c -> (b h w c)').shape
# Out:
# (165888,)

# %% [markdown]
# # **Axis Decomposition**

# %%
# decomposition is the inverse process - represent an axis as a combination of new axes
# several decompositions possible, so b1=2 is to decompose 6 to b1=2 and b2=3
rearrange(ims, '(b1 b2) h w c -> b1 b2 h w c ', b1=2).shape
# Out:
# (2, 3, 96, 96, 3)

# %%
# finally, combine composition and decomposition:
rearrange(ims, '(b1 b2) h w c -> (b1 h) (b2 w) c ', b1=2)

# %%
# slightly different composition: b1 is merged with width, b2 with height
# ... so letters are ordered by w then by h
rearrange(ims, '(b1 b2) h w c -> (b2 h) (b1 w) c ', b1=2)

# %%
# move part of width dimension to height.
# we should call this width-to-height as image width shrunk by 2 and height doubled.
# but all pixels are the same!
# Can you write reverse operation (height-to-width)?
rearrange(ims, 'b h (w w2) c -> (h w2) (b w) c', w2=2)

# %% [markdown]
# # **Axis Order Matters**

# %%
# compare with the next example
rearrange(ims, 'b h w c -> h (b w) c')

# %%
# order of axes in composition is different
# rule is just as for digits in the number: leftmost digit is the most significant,
# while neighboring numbers differ in the rightmost axis.

# you can also think of this as lexicographic sort
rearrange(ims, 'b h w c -> h (w b) c')

# %%
# what if b1 and b2 are reordered before composing to width?
rearrange(ims, '(b1 b2) h w c -> h (b1 b2 w) c ', b1=2) # produces 'einops'
rearrange(ims, '(b1 b2) h w c -> h (b2 b1 w) c ', b1=2) # produces 'eoipns'

# %% [markdown]
# # einops.reduce

# %%
# average over batch
reduce(ims, 'b h w c -> h w c', 'mean')

# %%
# the previous is identical to familiar:
ims.mean(axis=0)
# but is so much more readable

# %%
# Example of reducing of several axes
# besides mean, there are also min, max, sum, prod
reduce(ims, 'b h w c -> h w', 'min')

# %%
# this is mean-pooling with 2x2 kernel
# image is split into 2x2 patches, each patch is averaged
reduce(ims, 'b (h h2) (w w2) c -> h (b w) c', 'mean', h2=2, w2=2)

# %%
# max-pooling is similar
# result is not as smooth as for mean-pooling
reduce(ims, 'b (h h2) (w w2) c -> h (b w) c', 'max', h2=2, w2=2)

# %%
# yet another example. Can you compute result shape?
reduce(ims, '(b1 b2) h w c -> (b2 h) (b1 w)', 'mean', b1=2)

# %% [markdown]
# # einops.repeat

# %%
# repeat along a new axis. New axis can be placed anywhere
repeat(ims[0], 'h w c -> h new_axis w c', new_axis=5).shape
# Out:
# (96, 5, 96, 3)

# %%
# shortcut
repeat(ims[0], 'h w c -> h 5 w c').shape
# Out:
# (96, 5, 96, 3)

# %%
# repeat along w (existing axis)
repeat(ims[0], 'h w c -> h (repeat w) c', repeat=3)

# %%
# repeat along two existing axes
repeat(ims[0], 'h w c -> (2 h) (2 w) c')

# %%
# order of axes matters as usual - you can repeat each element (pixel) 3 times
# by changing order in parenthesis
repeat(ims[0], 'h w c -> h (w repeat) c', repeat=3)

# %% [markdown]
# ## Assignment 3

# %% [markdown]
# #### 1. What is Einsum notation, and why is it useful in deep learning?

# %% [markdown]
# Einsum notation is a compact and expressive way to represent tensor operations using Einstein summation convention. It simplifies complex matrix operations by reducing code complexity and improving readability. Generally, while performing tensor operations using NumPy, TensorFlow, PyTorch, etc., we need to carefully manage the shapes and sizes of tensors and use different functions for different operations, like `matmul` for matrix multiplication, `diag` for diagonal extraction, `sum` to sum along a particular axis, `transpose` for transposing a tensor/matrix, and `trace` to find the trace. However, with `einsum`, it's just one function that makes tensor operations much more readable and easier to implement. While it may not be optimized for performance for all operations, especially for larger tensors, it's still one of the best ways to get started and intuitively understand tensor operations.

# %% [markdown]
# #### 2.  Given two vectors a and b, both of length I, how would you compute their dot product using Einsum notation?

# %%
from torch import einsum

a = torch.randn((1, 5)) 
b = torch.randn((1, 5))

a_unit = a / torch.norm(a)
b_unit = b / torch.norm(b)

# %%
a.shape
# Out:
# torch.Size([1, 5])

# %%
a_unit
# Out:
# tensor([[ 0.2965,  0.5213, -0.7910, -0.0424, -0.1134]])

# %%
b_unit
# Out:
# tensor([[-0.6305, -0.0045,  0.2686,  0.5730, -0.4494]])

# %%
einsum("ij, ij -> ", a_unit, b_unit)
# Out:
# tensor(-0.3751)

# %%
torch.dot(a_unit.flatten(), b_unit.flatten())
# Out:
# tensor(-0.3751)

# %%
einsum("i, i -> ", a_unit.flatten(), b_unit.flatten())
# Out:
# tensor(-0.3751)

# %% [markdown]
# #### 3. Explain how Einsum can be used to perform a batch matrix multiplication in PyTorch. Provide a code example.
#
# Let's assume we have two matrix A and B, such that they can be multiplied, then we can use einsum('bij,bjk->bik', A, B) to multiply both the matrix using einsum, where b is the batchsize

# %%
import torch
from torch import einsum

# %%
import einops
batch_size = 4
n, m, p = 3, 2, 5

A = torch.randint(0, 10, (batch_size, n, m), dtype=torch.int)
B = torch.randint(0, 10, (batch_size, m, p), dtype=torch.int)

# Using einsum 
result_using_einsum = einsum("bij,bjk -> bik", A, B)
# Using matmul 
result_using_matmul = torch.matmul(A, B)

# %%
A
# Out:
# tensor([[[4, 3],
#          [5, 1],
#          [0, 8]],
#
#         [[3, 4],
#          [3, 0],
#          [8, 8]],
#
#         [[2, 7],
#          [4, 8],
#          [7, 1]],
#
#         [[0, 7],
#          [5, 9],
#          [8, 5]]], dtype=torch.int32)

# %%
B
# Out:
# tensor([[[3, 0, 5, 1, 3],
#          [8, 6, 5, 6, 7]],
#
#         [[0, 4, 2, 6, 8],
#          [3, 3, 8, 0, 1]],
#
#         [[8, 1, 1, 1, 2],
#          [5, 7, 1, 2, 4]],
#
#         [[0, 6, 0, 1, 4],
#          [9, 7, 9, 8, 0]]], dtype=torch.int32)

# %%
result_using_matmul == result_using_einsum
# Out:
# tensor([[[True, True, True, True, True],
#          [True, True, True, True, True],
#          [True, True, True, True, True]],
#
#         [[True, True, True, True, True],
#          [True, True, True, True, True],
#          [True, True, True, True, True]],
#
#         [[True, True, True, True, True],
#          [True, True, True, True, True],
#          [True, True, True, True, True]],
#
#         [[True, True, True, True, True],
#          [True, True, True, True, True],
#          [True, True, True, True, True]]])

# %%
result_using_matmul
# Out:
# tensor([[[36, 18, 35, 22, 33],
#          [23,  6, 30, 11, 22],
#          [64, 48, 40, 48, 56]],
#
#         [[12, 24, 38, 18, 28],
#          [ 0, 12,  6, 18, 24],
#          [24, 56, 80, 48, 72]],
#
#         [[51, 51,  9, 16, 32],
#          [72, 60, 12, 20, 40],
#          [61, 14,  8,  9, 18]],
#
#         [[63, 49, 63, 56,  0],
#          [81, 93, 81, 77, 20],
#          [45, 83, 45, 48, 32]]], dtype=torch.int32)

# %%
result_using_einsum
# Out:
# tensor([[[36, 18, 35, 22, 33],
#          [23,  6, 30, 11, 22],
#          [64, 48, 40, 48, 56]],
#
#         [[12, 24, 38, 18, 28],
#          [ 0, 12,  6, 18, 24],
#          [24, 56, 80, 48, 72]],
#
#         [[51, 51,  9, 16, 32],
#          [72, 60, 12, 20, 40],
#          [61, 14,  8,  9, 18]],
#
#         [[63, 49, 63, 56,  0],
#          [81, 93, 81, 77, 20],
#          [45, 83, 45, 48, 32]]], dtype=torch.int32)

# %% [markdown]
# #### 4. What are the primary operations provided by einops, and what is the purpose of each?

# %% [markdown]
# It porvides many funtions, but primary are like rearrange, reduce, and repeat.
#
# a) `Rearrange` - it helps to reshape the tensor, merging multiple axes into one or splittle one to multiple
#
# b) `Reduce` - it helps in summing elements along specified dimensions
#
# c) `Repeat` - it helps in larger tensors by repeating elements of the input tensor.

# %% [markdown]
# #### 5. Using einops, how would you convert a 4D tensor of shape (b, h, w, c) into a 1D tensor while preserving the number of elements?

# %%
ims = np.load('resources/test_images.npy', allow_pickle=False)
# There are 6 images of shape 96x96 with 3 color channels packed into tensor
print(ims.shape, ims.dtype)
# Out:
# (6, 96, 96, 3) float64

# %%
einops.rearrange(ims, 'b h w c -> b (h w c)').shape
# Out:
# (6, 27648)

# %%
einops.rearrange?
# Out:
# Signature:
# einops.rearrange(
#     tensor: Union[~Tensor, List[~Tensor]],
#     pattern: str,
#     **axes_lengths,
# ) -> ~Tensor
# Docstring:
# einops.rearrange is a reader-friendly smart element reordering for multidimensional tensors.
# This operation includes functionality of transpose (axes permutation), reshape (view), squeeze, unsqueeze,
# stack, concatenate and other operations.
#
# Examples for rearrange operation:
#
# ```python
# # suppose we have a set of 32 images in "h w c" format (height-width-channel)
# >>> images = [np.random.randn(30, 40, 3) for _ in range(32)]
#
# # stack along first (batch) axis, output is a single array
# >>> rearrange(images, 'b h w c -> b h w c').shape
# (32, 30, 40, 3)
#
# # concatenate images along height (vertical axis), 960 = 32 * 30
# >>> rearrange(images, 'b h w c -> (b h) w c').shape
# (960, 40, 3)
#
# # concatenated images along horizontal axis, 1280 = 32 * 40
# >>> rearrange(images, 'b h w c -> h (b w) c').shape
# (30, 1280, 3)
#
# ...

# %% [markdown]
# #### 6.  Write the einops operation to perform mean-pooling with a 2x2 kernel on a 4D tensor of shape (b, h, w, c). What will be the shape of the resulting tensor if h and w are both even?

# %%
ims = np.load('resources/test_images.npy', allow_pickle=False)
ims_tensor = torch.tensor(ims)
# There are 6 images of shape 96x96 with 3 color channels packed into tensor
print(ims_tensor.shape, ims_tensor.dtype)
# Out:
# torch.Size([6, 96, 96, 3]) torch.float64

# %%
result = einops.reduce(ims_tensor, 'b (h2 h) (w2 w) c -> b h2 w2 c', 'mean', h2=2, w2=2)

# %%
result.shape
# Out:
# torch.Size([6, 2, 2, 3])

# %%
import numpy as np
import torch
from einops import reduce

# Load the input tensor
ims = np.load('resources/test_images.npy', allow_pickle=False)
print("Original tensor shape:", ims.shape, ims.dtype)

# Perform mean-pooling with a 2x2 kernel
pooled_tensor = reduce(ims, 'b (h h2) (w w2) c -> b h w c', 'mean', h2=2, w2=2)

# Print the shape of the pooled tensor
print("Pooled tensor shape:", pooled_tensor.shape)
# Out:
# Original tensor shape: (6, 96, 96, 3) float64
# Pooled tensor shape: (6, 48, 48, 3)
